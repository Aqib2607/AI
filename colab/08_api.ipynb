# %% [markdown]
# # 08. OpenAI-Compatible REST API Gateway
#
# Launches the OpenAI-compatible REST server supporting `/health`, `/v1/models`, and `/v1/chat/completions` with Server-Sent Events (SSE) streaming and Bearer token security.

# %%
# Launch API Gateway in background or foreground
import os
os.environ['COLI_HOST'] = '127.0.0.1'
os.environ['COLI_PORT'] = '8000'
os.environ['COLI_API_KEY'] = 'coli_sk_live_secret_key_123'
os.environ['MODEL_DIR'] = '/content/drive/MyDrive/AI/GLM-5.2/model'

# !python api/app.py &

# %%
# Verify health status via health probe
# !python scripts/health_check.py --api-key 'coli_sk_live_secret_key_123'

# %%
# Test chat completion request with SSE stream
import requests

url = 'http://127.0.0.1:8000/v1/chat/completions'
headers = {'Authorization': 'Bearer coli_sk_live_secret_key_123'}
payload = {
    'model': 'glm-5.2-744b-moe-int4',
    'messages': [{'role': 'user', 'content': 'Explain quantum computing in one sentence.'}],
    'stream': True
}

with requests.post(url, headers=headers, json=payload, stream=True) as r:
    for line in r.iter_lines():
        if line:
            print(line.decode('utf-8'))
