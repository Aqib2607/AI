# %% [markdown]
# # 07. Local NVMe vs. Google Drive FUSE Benchmark
#
# Empirically benchmarks and records the performance differences between direct Google Drive streaming and Local NVMe staging across 5 deterministic test prompts.

# %%
LOCAL_DIR = '/content/model'
DRIVE_DIR = '/content/drive/MyDrive/AI/GLM-5.2/model'
BENCHMARK_DIR = '/content/drive/MyDrive/AI/GLM-5.2/benchmarks'

# Run comparative benchmark suite
# !python scripts/benchmark.py \
  --local-dir "{LOCAL_DIR}" \
  --drive-dir "{DRIVE_DIR}" \
  --output-dir "{BENCHMARK_DIR}" \
  --repetitions 3

# %%
# Generate consolidated engineering report
# !python scripts/generate_report.py \
  --model-dir "{DRIVE_DIR}" \
  --benchmark-dir "{BENCHMARK_DIR}" \
  --output "/content/drive/MyDrive/AI/GLM-5.2/engineering_report.md"
