# %% [markdown]
# # 06. GLM-5.2 Inference & Prompt Evaluation
#
# Runs deterministic and interactive validation prompts through the compiled Colibrì engine to measure token generation latency, startup time, and memory residency.

# %%
import os

# Optional: Stage model onto local NVMe disk for faster inference
LOCAL_MODEL = '/content/model'
DRIVE_MODEL = '/content/drive/MyDrive/AI/GLM-5.2/model'

# If disk space permits, copy shards locally, or stream directly
TARGET_MODEL_DIR = DRIVE_MODEL

# %%
# Interactive CLI prompt execution
# !/content/colibri/coli chat --model "{TARGET_MODEL_DIR}"
