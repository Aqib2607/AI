# %% [markdown]
# # 01. Google Colab Environment & Hardware Diagnostic
#
# This notebook inspects the Google Colab runtime to verify CPU vector capability, RAM allocation, GPU presence, disk space, and compiler toolchains.

# %%
# 1. Bootstrap repository in Colab runtime
import os, sys, subprocess
REPO_DIR = '/content/glm52-drive-runtime'
if not os.path.exists(REPO_DIR):
    print(f"Cloning GLM-5.2 repository into {REPO_DIR}...")
    subprocess.run(['git', 'clone', 'https://github.com/Aqib2607/AI.git', REPO_DIR], check=True)

# !pip install -q pyyaml psutil rich tabulate requests

# %%
# 2. Execute environment check diagnostic via absolute repository path
# !python /content/glm52-drive-runtime/scripts/environment_check.py

# %%
# 3. Verify compiler and OpenMP flags
# !gcc --version
# !make --version
# !lscpu | grep -E 'Model name|Socket|Thread|NUMA|CPU\(s\)|flags'
