# %% [markdown]
# # 07. Empirical Storage Performance Benchmarking
#
# Runs multi-trial standardized evaluation comparing Local NVMe storage (`/content/model`) vs. Google Drive FUSE streaming (`/content/drive/MyDrive/AI - Google Drive/GLM-5.2/model`).

# %%
import os

DRIVE_MODEL_DIR = '/content/drive/MyDrive/AI - Google Drive/GLM-5.2/model'
LOCAL_MODEL_DIR = '/content/model'
OUTPUT_DIR = '/content/drive/MyDrive/AI - Google Drive/GLM-5.2/benchmarks'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# !python scripts/benchmark.py \
  --local-dir "{LOCAL_MODEL_DIR}" \
  --drive-dir "{DRIVE_MODEL_DIR}" \
  --output-dir "{OUTPUT_DIR}" \
  --repetitions 3

# %%
# Generate consolidated markdown report
# !python scripts/generate_report.py \
  --model-dir "{DRIVE_MODEL_DIR}" \
  --benchmark-dir "{OUTPUT_DIR}" \
  --output "/content/drive/MyDrive/AI - Google Drive/GLM-5.2/benchmarks/summary.md"
