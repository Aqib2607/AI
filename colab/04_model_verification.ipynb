# %% [markdown]
# # 04. Model Integrity & Header Verification
#
# Performs fast, non-destructive Safetensors header validation across all 38 shards to confirm readiness before launching inference.

# %%
DRIVE_MODEL_DIR = '/content/drive/MyDrive/AI/GLM-5.2/model'

# 1. Model inventory scan
# !python scripts/model_inventory.py --model-dir "{DRIVE_MODEL_DIR}"

# %%
# 2. Integrity and Safetensors header verification
# !python scripts/model_verify.py --model-dir "{DRIVE_MODEL_DIR}" --expected-shards 38
